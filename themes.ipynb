# %% [markdown]
# <a href="https://colab.research.google.com/github/namitabagri/Topic-Modelling-Based-Classifier/blob/main/themes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 70.6 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import nltk
import numpy as np
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import gensim
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
url = "https://raw.githubusercontent.com/namitabagri/Topic-Modelling-Based-Classifier/main/synthetic_app_issues.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#        ticket  application week_start_date  \
# 0  GMC3005398        excel      2002-05-15
# 1  GMC3491287  share point      2002-05-15
# 2  GMC3241859        excel      2002-05-15
# 3  GMC3289072        excel      2002-05-15
# 4  GMC3573428        excel      2002-05-15
#
#                                          description
# 0  issue in managing file permission in one drive...
# 1  excel chart formatting resets automatically fo...
# 2  issue in managing file permission in one drive...
# 3  excel formula =SUM(A1:A5) not working properly...
# 4  the file is not syncing on the one drive syste...

# %%
df['application'].unique()
# Out:
# array(['excel', 'share point', 'one drive', 'ppt'], dtype=object)

# %%
df=df.drop(columns=['week_start_date', 'application'],axis=1)

# %%
docs = df['description'].astype(str).tolist()

# %%
# Simple preprocessing
stop_words = set(stopwords.words('english'))
def preprocess(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    tokens = text.split()
    tokens = [t for t in tokens if t not in stop_words and len(t)>1]
    return " ".join(tokens)

docs_clean = [preprocess(d) for d in docs]

# %%
# Vectorize (BoW)
vectorizer = CountVectorizer(max_df=0.85, min_df=2, max_features=5000, ngram_range=(1,2))
dtm = vectorizer.fit_transform(docs_clean)  # document-term matrix (sparse)

# %%
# Fit LDA
n_topics = 4
lda = LatentDirichletAllocation(n_components=n_topics,
                                max_iter=50,
                                learning_method='batch',
                                doc_topic_prior=0.1,
                                random_state=42)
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(doc_topic_prior=0.1, max_iter=50, n_components=4,
#                           random_state=42)

# %%
feature_names = vectorizer.get_feature_names_out()
#feature_names

# %%
lda.components_
# Out:
# array([[ 0.20000004,  0.20000004,  0.20000004,  0.20000004, 16.19932802,
#         16.19932802,  0.20358636,  0.20358636,  0.20000006,  0.20000006,
#          0.20137302,  0.20137302,  0.20000003,  0.20000003,  0.20000003,
#          0.20000003,  0.20137302,  0.20137302,  0.20000005,  0.20358636,
#          0.20358636,  0.20490926,  0.20564753, 11.1958772 ,  0.2000001 ,
#          0.2000001 , 16.19932802, 16.19932802,  0.20000005,  0.20000004,
#          0.20000005,  0.20000003,  0.20000003,  0.20000007,  0.20000007,
#          0.20000003,  0.20000003,  0.20564753,  0.20564753,  0.20128991,
#          0.20137302,  0.20000004,  0.20000007,  0.20000007,  0.20000004,
#          0.20000003,  0.20000005,  0.20137302,  0.20137302,  0.20000004,
#          0.20000004,  0.20000003,  0.20000003, 16.19932802, 16.19932802,
#          0.20000004,  0.20000003,  0.20000003,  0.2000001 ,  0.2000001 ,
#          0.20000007,  0.20000007, 11.19578488, 11.19578488,  0.20000004,
#          0.20000004,  0.20000005,  0.20000005,  0.2000001 ,  0.2000001 ,
#          0.20000007,  0.20000004,  0.20000003,  0.20000006,  0.20000006,
#          0.20000012,  0.20000003,  0.2000001 , 16.19957542,  0.20000006,
#         16.19932802,  0.20000003,  0.20000003,  0.20000003,  0.20000004,
#          0.20000004,  0.20137302,  0.20137302,  0.20000012,  0.20000012,
#          0.20000006,  0.20000006,  0.20000007,  0.20000007,  0.20000003,
#          0.20000003,  0.20000004,  0.20000004,  0.20564753,  0.20564753,
  0.20000001,
#          0.20000001,  0.20000001,  0.20000001, 20.19997473, 20.19997473,
#         22.1994509 , 22.1994509 , 22.19943688, 22.1994509 ,  0.20000001,
#          0.20000001,  0.20000001,  0.20000001,  0.20000001, 20.19985515,
#          0.20000001, 20.19993721,  0.20000001,  0.20000001,  0.20000001]])

# %%
def print_topics(model, n_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic #{idx}: ",
              [feature_names[i] for i in topic.argsort()[-n_top_words:]])

print_topics(lda)
# Out:
# Topic #0:  ['playing', 'ppt animations', 'shared contact', 'contact admin', 'user', 'mail', 'mail com', 'user mail', 'contact user', 'ppt']
# Topic #1:  ['level', 'permission system', 'point due', 'upload', 'unable upload', 'system level', 'unable', 'user unable', 'upload file', 'user']
# Topic #2:  ['contact admin', 'mail', 'user mail', 'mail com', 'admin', 'company com', 'company', 'admin company', 'excel', 'user']
# Topic #3:  ['permission', 'one', 'one drive', 'drive', 'file', 'contact support', 'example', 'example com', 'support', 'support example']

# %%
topic_to_label = {
    0: "ppt",
    1: "share point" ,
    2: "excel",
    3: "one drive"
}

# %%
# Document-topic probability matrix
doc_topic_matrix = lda.transform(dtm)
dominant_topic_per_doc = np.argmax(doc_topic_matrix, axis=1)

# %%
df['topic_number'] = dominant_topic_per_doc
df['topic_label'] = df['topic_number'].map(topic_to_label)

# %%
df
# Out:
#          ticket  application  \
# 0    GMC3005398        excel
# 1    GMC3491287  share point
# 2    GMC3241859        excel
# 3    GMC3289072        excel
# 4    GMC3573428        excel
# ..          ...          ...
# 195  GMC3609447          ppt
# 196  GMC3713946  share point
# 197  GMC3011455    one drive
# 198  GMC3254224    one drive
# 199  GMC3840175          ppt
#
#                                            description  predicted_topic  \
# 0    issue in managing file permission in one drive...                3
# 1    excel chart formatting resets automatically fo...                2
# 2    issue in managing file permission in one drive...                3
# 3    excel formula =SUM(A1:A5) not working properly...                2
# 4    the file is not syncing on the one drive syste...                0
# ..                                                 ...              ...
# 195  ppt crashes when adding images from http://com...                0
# 196  the excel sheet is locked for editing by admin...                2
# 197  excel formula =SUM(A1:A5) not working properly...                2
# 198  ppt crashes when adding images from http://com...                0
# 199  ppt animations not playing when shared over ht...                0
#
#      topic_number topic_label
# 0               3   one drive
# 1               2       excel
# 2               3   one drive
# 3               2       excel
# 4               0         ppt
# ..            ...         ...
# 195             0         ppt
# 196             2       excel
# 197             2       excel
# 198             0         ppt
# 199             0         ppt
#
# [200 rows x 6 columns]

# %%
df['topic_label'].value_counts()
# Out:
# topic_label
# excel          80
# ppt            61
# share point    37
# one drive      22
# Name: count, dtype: int64

# %%
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
import numpy as np

# Prepare text data as tokenized documents again (same preprocessing as before)
texts = df['description'].apply(lambda x: x.split()).tolist()

# Create a Gensim dictionary & corpus
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Convert sklearn LDA topics to gensim format
topics = []
for topic_weights in lda.components_:
    top_word_ids = topic_weights.argsort()[:-11:-1]  # top 10 words
    topics.append([vectorizer.get_feature_names_out()[i] for i in top_word_ids])

# Calculate coherence (C_V)
coherence_model = CoherenceModel(topics=topics,
                                 texts=texts,
                                 dictionary=dictionary,
                                 coherence='c_v')
coherence_score = coherence_model.get_coherence()

print(f"Coherence Score: {coherence_score:.4f}")
# Out:
# Coherence Score: 0.7743
